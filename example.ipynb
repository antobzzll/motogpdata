# %% [markdown]
# # `motogpdata` - Python motogp.com API handler

# %% [markdown]
# ## `motogpdata.api.Handler()`
#
# This class is used to retrieve data on a particular **year** and **category** of the MotoGP Championship.

# %%
from motogpdata.api import Handler, season_range_results
motogp = Handler(verbose=True)

# %% [markdown]
# When initiated, the class can be used to explore all the seasons available with the `motogpdata.seasons` attribute. For example, to print the last 10 seasons:

# %%
motogp.seasons[:10]
# Out:
# [2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013]

# %% [markdown]
# Or to print the first 10 seasons:

# %%
motogp.seasons[:-11:-1]
# Out:
# [1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958]

# %% [markdown]
# ### `motogpdata.api.Handler.load_season()`
#
# To load a specific season - and to access its data -, use the `motogpdata.api.Handler.load_season()` method.

# %%
motogp.load_season(season=2022, category='MotoGP')
# Out:
# Loaded MotoGP season 2022 (db8dc197-c7b2-4c1b-b3a4-6dc534c014ef)
# Available categories: ['MotoGP', 'Moto2', 'Moto3', 'MotoE']
# Available events: ['QAT', 'INA', 'ARG', 'AME', 'POR', 'SPA', 'FRA', 'ITA', 'CAT', 'GER', 'NED', 'GBR', 'AUT', 'RSM', 'ARA', 'JPN', 'THA', 'AUS', 'MAL', 'VAL']

# %% [markdown]
# ### `motogpdata.api.Handler.riders()`
#
# Once a season has been loaded with the previous method, information about the riders who participated in that year is accessible with the `motogpdata.api.Handler.riders()` method.

# %%
riders2022 = motogp.riders()
riders2022.head()
# Out:
# Riders:
#                                      id    name    surname nickname  \
# 0  fe9fa956-0cd0-4009-9484-25e7cb5bdf88  Andrea  Dovizioso     None
# 1  4a439bde-305a-4995-b3e7-783fa99f784a  Johann      Zarco     None
# 2  f5f54b1e-b2c3-4bfe-9f04-e5f722a7b9e4  Stefan      Bradl     None
# 3  c403dc28-7881-4d3d-99d4-5fe5eb1236e5  Danilo   Petrucci     None
# 4  5dfc20db-c3c4-4ecd-9c7c-f6cfd042031a    Luca     Marini     None
#
#       birth_city  birth_date  years_old  published  legacy_id  \
# 0  Forlimpopoli   1986-03-23         35       True       5885
# 1         Cannes  1990-07-16         31       True       7236
# 2       Augsburg  1989-11-29         32       True       6267
# 3          Terni  1990-10-24         31       True       8148
# 4         Urbino  1997-08-10         24       True       8431
#
#    current_career_step.season  ...  \
# 0                        2022  ...
# 1                        2022  ...
# 2                        2022  ...
# 3                        2022  ...
# 4                        2022  ...
#
#    current_career_step.pictures.profile.secondary  \
# 0                                            None
# 1                                            None
# 2                                            None
# 3                                            None
# 4                                            None
#
#               current_career_step.pictures.bike.main  \
# 0  https://photos.motogp.com/riders/4/7/47a5a003-...
# 1  https://photos.motogp.com/riders/b/b/bbe2f418-...
# 2                                               None
# 3                                               None
# 4  https://photos.motogp.com/riders/2/5/25155175-...
#
#   current_career_step.pictures.bike.secondary  \
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
#
#             current_career_step.pictures.helmet.main  \
# 0  https://photos.motogp.com/riders/4/7/47a5a003-...
# 1  https://photos.motogp.com/riders/8/1/8121164e-...
# 2                                               None
# 3                                               None
# 4  https://photos.motogp.com/riders/2/5/25155175-...
#
#   current_career_step.pictures.helmet.secondary  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
#
#                  current_career_step.pictures.number  \
# 0  https://photos.motogp.com/riders/a/a/aaaffe16-...
# 1  https://photos.motogp.com/riders/1/5/15ef8e96-...
# 2                                               None
# 3                                               None
# 4  https://photos.motogp.com/riders/b/d/bd54082c-...
#
#                current_career_step.pictures.portrait  country.iso  \
# 0  https://photos.motogp.com/riders/2/a/2a73aa8a-...           IT
# 1  https://photos.motogp.com/riders/5/4/545fcb36-...           FR
# 2                                               None           DE
# 3  https://photos.motogp.com/riders/f/0/f07a67cc-...           IT
# 4  https://photos.motogp.com/riders/9/d/9d958b49-...           IT
#
#   country.name current_career_step.team
# 0        Italy                      NaN
# 1       France                      NaN
# 2      Germany                      NaN
# 3        Italy                      NaN
# 4        Italy                      NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ### `motogpdata.api.Handler.results()`
#
# To retrieve the results of a MotoGP session, use the `motogpdata.api.Handler.results()` method. If the `event` parameter is not specified, all events will be downloaded and concatenated in a single dataframe.

# %%
season_results = motogp.results(
    # event='QAT', 
    # session='RAC', 
    # s_num=0
    )

season_results.to_csv("data/2022.csv")
# Out:
# Retrieving results for all events in season 2022:
# 	* QAT (0561c82b-4738-4bb6-88d0-6df77f002a43) ... Ok.
# 	* INA (0964b830-bed9-48be-9abe-fb44195f97eb) ... Ok.
# 	* ARG (d05f42a3-4b65-4d04-9612-fd148880750e) ... Ok.
# 	* AME (b1febdc8-cebe-4db4-b0c7-b4035006b15a) ... Ok.
# 	* POR (713255bd-2e76-4aad-a337-529a054cf7d2) ... Ok.
# 	* SPA (0a9422c3-0870-49c9-86e6-4d8aad0522dd) ... Ok.
# 	* FRA (bc520d3f-a3e9-4b46-be38-4f951a1839e5) ... Ok.
# 	* ITA (e59414f7-de19-400d-b7d2-6fce2b3c5448) ... Ok.
# 	* CAT (4d47e417-fae3-44bd-bfdf-929c1041e6fe) ... Ok.
# 	* GER (4d54a9bd-bc4e-4389-90fb-018af5de1a0b) ... Ok.
# 	* NED (726dbaae-6b5a-49b9-982a-c4f46cfed0a5) ... Ok.
# 	* GBR (d7c76a83-c138-4c19-9565-c7c4400c3d94) ... Ok.
# 	* AUT (486e0780-619f-4fba-a951-2856d4c2747e) ... Ok.
# 	* RSM (7d810351-1bf8-451e-8fba-f3ff2ae0f29e) ... Ok.
# 	* ARA (02b8d4c2-f6d2-4937-9725-3422a0cb2454) ... Ok.
# 	* JPN (496b5a1e-9fcd-4ccb-abcb-e0d21d2d76d8) ... Ok.
# 	* THA (1c5fcb91-cfbc-4dab-86e9-6a9da6024d4f) ... Ok.
# 	* AUS (0d38138d-6545-4093-a3ac-c8506baf499f) ... Ok.
# 	* MAL (d913e4a4-782b-48c4-a5cd-f7947ec62aa4) ... Ok.
# 	* VAL (048b155e-5f65-4aa4-b7dd-b919ebcdddeb) ... Ok.
# Dataframe concatenated.

# %% [markdown]
# If results are downloaded for all events, it is possible to retrieve reults for a specific event with a simple `pandas` subset on the `event_name` column.

# %%
season_results[season_results['event_name'] == 'QAT'].head()
# Out:
#                                      id  position  average_speed  total_laps  \
# 0  d34b642c-d22d-4fc6-9140-e4ccb84a3370       1.0          168.2          22
# 1  4bfde940-8a4d-4f59-b7d1-8be73e479d3a       2.0          168.1          22
# 2  a07bf2dd-6444-4f70-b66f-c63e8eb30ca8       3.0          168.1          22
# 3  afc5a08d-cd32-4f1d-98a9-083d458f7281       4.0          168.0          22
# 4  45576e63-0b83-4a72-a4dc-febca9c8b2c3       5.0          167.9          22
#
#          time  points  status                              rider.id  \
# 0  42:13.1980      25  INSTND  ff225c9d-64a2-43ac-a70e-62cf385a85a1
# 1  42:13.5440      20  INSTND  ba579548-f026-402b-a607-38db5317d33f
# 2  42:14.5490      16  INSTND  40c19361-abe5-46e8-bed9-b3fa648dd7ac
# 3  42:15.4400      13  INSTND  4cff2dfb-2feb-4264-9a17-8a67189c204c
# 4  42:17.2970      11  INSTND  f55b433d-38b8-4d1d-bb3a-a709c82a0260
#
#    rider.full_name rider.country.iso  ...  \
# 0  Enea Bastianini                IT  ...
# 1      Brad Binder                ZA  ...
# 2    Pol Espargaro                ES  ...
# 3  Aleix Espargaro                ES  ...
# 4     Marc Marquez                ES  ...
#
#                          team.season.id team.season.year  team.season.current  \
# 0  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022                False
# 1  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022                False
# 2  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022                False
# 3  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022                False
# 4  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022                False
#
#                          constructor.id constructor.name  \
# 0  b9d93efb-3cd0-4681-9de4-c412a866d568           Ducati
# 1  be77c017-cc37-41eb-aa09-2977f1789b0f              KTM
# 2  3a036648-7b14-4257-8c62-245e47e4d42b            Honda
# 3  10d5e2bc-4b0b-4875-b936-3962fbb1b877          Aprilia
# 4  3a036648-7b14-4257-8c62-245e47e4d42b            Honda
#
#   constructor.legacy_id  gap.first gap.lap  \
# 0                   110      0.000       0
# 1                   298      0.346       0
# 2                     1      1.351       0
# 3                     7      2.242       0
# 4                     1      4.099       0
#
#                                event_id  event_name
# 0  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 1  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 2  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 3  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 4  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
#
# [5 rows x 27 columns]

# %% [markdown]
# The `results()` method can also retrieve classifications for other types of session, such as FP, WUP, Q. For FP and Q, the number of the session should also be specified (with argument `s_num`); ex.: Q1 below.

# %%
motogp.load_season(
    season=2016,
    category='MotoGP'
    )
motogp.results(event='QAT', session='Q', s_num=1).head()
# Out:
# Loaded MotoGP season 2016 (ba354746-c4da-4dc8-8b8e-776fcc43287d)
# Available categories: ['MotoGP', 'Moto2', 'Moto3']
# Available events: ['QAT', 'ARG', 'AME', 'SPA', 'FRA', 'ITA', 'CAT', 'NED', 'GER', 'AUT', 'CZE', 'GBR', 'RSM', 'ARA', 'JPN', 'AUS', 'MAL', 'VAL']
# Retrieving results for event QAT in season 2016:
# 	* QAT (040db5cc-c029-4756-ba07-10de7d987a27) ... Ok.
#                                      id  position  total_laps  top_speed  \
# 0  e467cfce-da3a-4185-84f2-838c060fd181       1.0           3      331.6
# 1  7132f476-5e1c-4280-a027-89e7c79e3003       2.0           5      332.4
# 2  72bfe6e5-3a4e-45ef-9a17-bb1b25027f16       3.0           6      331.5
# 3  9addacac-0785-4752-a160-28561ef881e2       4.0           7      336.1
# 4  2264cc1a-d4c7-4c58-8905-fbeed08c2537       5.0           7      326.0
#
#    status                              rider.id  rider.full_name  \
# 0  INSTND  c2e99a2c-ec5b-4757-8728-ed3254ebbeee    Cal Crutchlow
# 1  INSTND  fa277754-e5c4-434f-a50d-f7fb9c2c69d8    Bradley Smith
# 2  INSTND  77359205-483f-4500-9a47-e92a0eea1484  Yonny Hernandez
# 3  INSTND  2c886bd0-8530-4e0b-b587-57070243079b   Eugene Laverty
# 4  INSTND  4cff2dfb-2feb-4264-9a17-8a67189c204c  Aleix Espargaro
#
#   rider.country.iso                                 rider.country.name  \
# 0                GB  United Kingdom of Great Britain and Northern I...
# 1                GB  United Kingdom of Great Britain and Northern I...
# 2                CO                                           Colombia
# 3                IE                                            Ireland
# 4                ES                                              Spain
#
#   rider.country.region_iso  ...  team.season.current  \
# 0                           ...                False
# 1                           ...                False
# 2                           ...                False
# 3                           ...                False
# 4                           ...                False
#
#                          constructor.id constructor.name  \
# 0  3a036648-7b14-4257-8c62-245e47e4d42b            Honda
# 1  babb4c4c-3608-4811-93ad-3b88cc407547           Yamaha
# 2  b9d93efb-3cd0-4681-9de4-c412a866d568           Ducati
# 3  b9d93efb-3cd0-4681-9de4-c412a866d568           Ducati
# 4  e1824280-b485-4f63-b176-834bbf47aa1c           Suzuki
#
#   constructor.legacy_id  best_lap.number best_lap.time  gap.first  gap.prev  \
# 0                     1              3.0    01:55.2910      0.000     0.000
# 1                     3              5.0    01:55.4900      0.199     0.199
# 2                   110              3.0    01:56.1570      0.866     0.667
# 3                   110              7.0    01:56.1860      0.895     0.029
# 4                     2              3.0    01:56.2380      0.947     0.052
#
#                                event_id event_name
# 0  040db5cc-c029-4756-ba07-10de7d987a27        QAT
# 1  040db5cc-c029-4756-ba07-10de7d987a27        QAT
# 2  040db5cc-c029-4756-ba07-10de7d987a27        QAT
# 3  040db5cc-c029-4756-ba07-10de7d987a27        QAT
# 4  040db5cc-c029-4756-ba07-10de7d987a27        QAT
#
# [5 rows x 27 columns]

# %%
motogp.sessions
# Out:
#                                      id type  number  \
# 0  b733c203-3ff8-4436-8538-c0fd6dcdc804   FP     1.0
# 1  2a9d2ed0-ebb0-4f58-a0e9-69ee6b41124e   FP     2.0
# 2  5b29a50b-95c1-4320-bb94-827ac54f913d   FP     3.0
# 3  05896eb2-6212-49a1-8a7a-328a56ee9b57   FP     4.0
# 4  711ddb29-de63-4eaf-ae58-ce0338bdd136    Q     1.0
# 5  118cff7b-555c-480a-af3f-38db0316d5a5    Q     2.0
# 6  10678ccc-5400-4d1b-9774-eaf728547cd9  WUP     0.0
# 7  e62f9cda-e659-4788-9818-1274bbc4ff18  RAC     0.0
#
#                         date    status                       circuit  \
# 0  2016-03-17T19:55:00+00:00  Official  Lusail International Circuit
# 1  2016-03-18T18:00:00+00:00  Official  Lusail International Circuit
# 2  2016-03-18T20:55:00+00:00  Official  Lusail International Circuit
# 3  2016-03-19T19:55:00+00:00  Official  Lusail International Circuit
# 4  2016-03-19T20:35:00+00:00  Official  Lusail International Circuit
# 5  2016-03-19T21:00:00+00:00  Official  Lusail International Circuit
# 6  2016-03-20T17:00:00+00:00  Official  Lusail International Circuit
# 7  2016-03-20T21:00:00+00:00  Official  Lusail International Circuit
#
#   condition.track condition.air condition.humidity condition.ground  ...  \
# 0             Dry           22º                47%              23º  ...
# 1             Dry           22º                40%              23º  ...
# 2             Dry           22º                43%              21º  ...
# 3             Dry           23º                37%              21º  ...
# 4             Dry           21º                55%              21º  ...
# 5             Dry           21º                60%              21º  ...
# 6             Dry           23º                56%              33º  ...
# 7             Dry           21º                71%              23º  ...
#
#                            session_files.session.url  \
# 0  https://resources.motogp.com/files/results/201...
# 1  https://resources.motogp.com/files/results/201...
# 2  https://resources.motogp.com/files/results/201...
# 3  https://resources.motogp.com/files/results/201...
# 4  https://resources.motogp.com/files/results/201...
# 5  https://resources.motogp.com/files/results/201...
# 6  https://resources.motogp.com/files/results/201...
# 7  https://resources.motogp.com/files/results/201...
#
#   session_files.session.menu_position  \
# 0                                   2
# 1                                   2
# 2                                   2
# 3                                   2
# 4                                   2
# 5                                   2
# 6                                   2
# 7                                   2
#
#                  session_files.best_partial_time.url  \
# 0  https://resources.motogp.com/files/results/201...
# 1  https://resources.motogp.com/files/results/201...
# 2  https://resources.motogp.com/files/results/201...
# 3  https://resources.motogp.com/files/results/201...
# 4  https://resources.motogp.com/files/results/201...
# 5  https://resources.motogp.com/files/results/201...
# 6  https://resources.motogp.com/files/results/201...
# 7
#
#   session_files.best_partial_time.menu_position  \
# 0                                             2
# 1                                             2
# 2                                             2
# 3                                             2
# 4                                             2
# 5                                             2
# 6                                             2
# 7                                             2
#
#                      session_files.maximum_speed.url  \
# 0  https://resources.motogp.com/files/results/201...
# 1  https://resources.motogp.com/files/results/201...
# 2  https://resources.motogp.com/files/results/201...
# 3  https://resources.motogp.com/files/results/201...
# 4  https://resources.motogp.com/files/results/201...
# 5  https://resources.motogp.com/files/results/201...
# 6  https://resources.motogp.com/files/results/201...
# 7
#
#   session_files.maximum_speed.menu_position  \
# 0                                         2
# 1                                         2
# 2                                         2
# 3                                         2
# 4                                         2
# 5                                         2
# 6                                         2
# 7                                         2
#
#                  session_files.combined_practice.url  \
# 0
# 1  https://resources.motogp.com/files/results/201...
# 2  https://resources.motogp.com/files/results/201...
# 3
# 4
# 5
# 6
# 7
#
#   session_files.combined_practice.menu_position  \
# 0                                             2
# 1                                             2
# 2                                             2
# 3                                             2
# 4                                             2
# 5                                             2
# 6                                             2
# 7                                             2
#
#            session_files.combined_classification.url  \
# 0
# 1
# 2
# 3
# 4
# 5  https://resources.motogp.com/files/results/201...
# 6
# 7
#
#   session_files.combined_classification.menu_position
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
# 5                                                  2
# 6                                                  2
# 7                                                  2
#
# [8 rows x 37 columns]

# %% [markdown]
# #### Retrieving results for multiple seasons with `motogpdata.api.season_range_results()`

# %%
range = season_range_results(season_start=2012, season_end=2019, category='MotoGP', session='RAC', s_num=0, verbose=True)
range['team.season.year'].unique()
# Out:
# 2012 - OK
# 2013 - OK
# 2014 - OK
# 2015 - OK
# 2016 - OK
# 2017 - OK
# 2018 - OK
# 2019 - OK
# array([2012., 2013., 2014., 2015., 2016., 2017., 2018., 2019.])
