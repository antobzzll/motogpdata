# %% [markdown]
# # `motogpdata` Python API handler

# %% [markdown]
# ## `motogpdata.MotoGPData()`
#
# This class is used to retrieve data on a particular **year** and **category** of the MotoGP Championship.

# %%
from motogpdata import MotoGPData
motogp = MotoGPData(verbose=True)

# %% [markdown]
# When initiated, the class can be used to explore all the seasons available with the `motogpdata.seasons` attribute. For example, to print the last 10 seasons:

# %%
motogp.seasons[:10]
# Out:
# [2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013]

# %% [markdown]
# Or to print the first 10 seasons:

# %%
motogp.seasons[:-11:-1]
# Out:
# [1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958]

# %% [markdown]
# ### `motogpdata.MotoGPData.load_season()`
#
# To load a specific season - and to access its data -, use the `motogpdata.MotoGPData.load_season()` method.

# %%
motogp.load_season(season=2022, category='MotoGP')
# Out:
# Loaded MotoGP season 2022 (db8dc197-c7b2-4c1b-b3a4-6dc534c014ef)
# Available categories: ['MotoGP', 'Moto2', 'Moto3', 'MotoE']
# Available events: ['QAT', 'INA', 'ARG', 'AME', 'POR', 'SPA', 'FRA', 'ITA', 'CAT', 'GER', 'NED', 'GBR', 'AUT', 'RSM', 'ARA', 'JPN', 'THA', 'AUS', 'MAL', 'VAL']

# %% [markdown]
# ### `motogpdata.MotoGPData.riders()`
#
# Once a season has been loaded with the previous method, information about the riders who participated in that year is accessible with the `motogpdata.MotoGPData.riders()` method.

# %%
riders2022 = motogp.riders()
riders2022.head()
# Out:
# Riders:
#                                      id    name    surname nickname  \
# 0  fe9fa956-0cd0-4009-9484-25e7cb5bdf88  Andrea  Dovizioso     None
# 1  4a439bde-305a-4995-b3e7-783fa99f784a  Johann      Zarco     None
# 2  f5f54b1e-b2c3-4bfe-9f04-e5f722a7b9e4  Stefan      Bradl     None
# 3  c403dc28-7881-4d3d-99d4-5fe5eb1236e5  Danilo   Petrucci     None
# 4  5dfc20db-c3c4-4ecd-9c7c-f6cfd042031a    Luca     Marini     None
#
#       birth_city  birth_date  years_old  published  legacy_id  \
# 0  Forlimpopoli   1986-03-23         35       True       5885
# 1         Cannes  1990-07-16         31       True       7236
# 2       Augsburg  1989-11-29         32       True       6267
# 3          Terni  1990-10-24         31       True       8148
# 4         Urbino  1997-08-10         24       True       8431
#
#    current_career_step.season  ...  \
# 0                        2022  ...
# 1                        2022  ...
# 2                        2022  ...
# 3                        2022  ...
# 4                        2022  ...
#
#    current_career_step.pictures.profile.secondary  \
# 0                                            None
# 1                                            None
# 2                                            None
# 3                                            None
# 4                                            None
#
#               current_career_step.pictures.bike.main  \
# 0  https://photos.motogp.com/riders/4/7/47a5a003-...
# 1  https://photos.motogp.com/riders/b/b/bbe2f418-...
# 2                                               None
# 3                                               None
# 4  https://photos.motogp.com/riders/2/5/25155175-...
#
#   current_career_step.pictures.bike.secondary  \
# 0                                        None
# 1                                        None
# 2                                        None
# 3                                        None
# 4                                        None
#
#             current_career_step.pictures.helmet.main  \
# 0  https://photos.motogp.com/riders/4/7/47a5a003-...
# 1  https://photos.motogp.com/riders/8/1/8121164e-...
# 2                                               None
# 3                                               None
# 4  https://photos.motogp.com/riders/2/5/25155175-...
#
#   current_career_step.pictures.helmet.secondary  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
#
#                  current_career_step.pictures.number  \
# 0  https://photos.motogp.com/riders/a/a/aaaffe16-...
# 1  https://photos.motogp.com/riders/1/5/15ef8e96-...
# 2                                               None
# 3                                               None
# 4  https://photos.motogp.com/riders/b/d/bd54082c-...
#
#                current_career_step.pictures.portrait  country.iso  \
# 0  https://photos.motogp.com/riders/2/a/2a73aa8a-...           IT
# 1  https://photos.motogp.com/riders/5/4/545fcb36-...           FR
# 2                                               None           DE
# 3  https://photos.motogp.com/riders/f/0/f07a67cc-...           IT
# 4  https://photos.motogp.com/riders/9/d/9d958b49-...           IT
#
#   country.name current_career_step.team
# 0        Italy                      NaN
# 1       France                      NaN
# 2      Germany                      NaN
# 3        Italy                      NaN
# 4        Italy                      NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ### `motogpdata.MotoGPData.results()`
#
# To retrieve the results of a MotoGP event, use the `motogpdata.MotoGPData.results()` method. In the `event` parameter is not specified, all events will be downloaded and concatenated in a single dataframe.

# %%
season_results = motogp.results()
# season_results.results(event='QAT')

season_results.to_csv("data/2022.csv")
# Out:
# Retrieving results for all events in season 2022:
# 	* QAT (0561c82b-4738-4bb6-88d0-6df77f002a43) ... Ok.
# 	* INA (0964b830-bed9-48be-9abe-fb44195f97eb) ... Ok.
# 	* ARG (d05f42a3-4b65-4d04-9612-fd148880750e) ... Ok.
# 	* AME (b1febdc8-cebe-4db4-b0c7-b4035006b15a) ... Ok.
# 	* POR (713255bd-2e76-4aad-a337-529a054cf7d2) ... Ok.
# 	* SPA (0a9422c3-0870-49c9-86e6-4d8aad0522dd) ... Ok.
# 	* FRA (bc520d3f-a3e9-4b46-be38-4f951a1839e5) ... Ok.
# 	* ITA (e59414f7-de19-400d-b7d2-6fce2b3c5448) ... Ok.
# 	* CAT (4d47e417-fae3-44bd-bfdf-929c1041e6fe) ... Ok.
# 	* GER (4d54a9bd-bc4e-4389-90fb-018af5de1a0b) ... Ok.
# 	* NED (726dbaae-6b5a-49b9-982a-c4f46cfed0a5) ... Ok.
# 	* GBR (d7c76a83-c138-4c19-9565-c7c4400c3d94) ... Ok.
# 	* AUT (486e0780-619f-4fba-a951-2856d4c2747e) ... Ok.
# 	* RSM (7d810351-1bf8-451e-8fba-f3ff2ae0f29e) ... Ok.
# 	* ARA (02b8d4c2-f6d2-4937-9725-3422a0cb2454) ... Ok.
# 	* JPN (496b5a1e-9fcd-4ccb-abcb-e0d21d2d76d8) ... Ok.
# 	* THA (1c5fcb91-cfbc-4dab-86e9-6a9da6024d4f) ... Ok.
# 	* AUS (0d38138d-6545-4093-a3ac-c8506baf499f) ... Ok.
# 	* MAL (d913e4a4-782b-48c4-a5cd-f7947ec62aa4) ... Ok.
# 	* VAL (048b155e-5f65-4aa4-b7dd-b919ebcdddeb) ... Ok.
# Dataframe concatenated.

# %% [markdown]
# If results are downloaded for all events, it is possible to retrieve reults for a specific event with a simple `pandas` subset on the `event_name` column.

# %%
season_results[season_results['event_name'] == 'QAT']
# Out:
#                                       id  position  average_speed  total_laps  \
# 0   d34b642c-d22d-4fc6-9140-e4ccb84a3370       1.0          168.2          22
# 1   4bfde940-8a4d-4f59-b7d1-8be73e479d3a       2.0          168.1          22
# 2   a07bf2dd-6444-4f70-b66f-c63e8eb30ca8       3.0          168.1          22
# 3   afc5a08d-cd32-4f1d-98a9-083d458f7281       4.0          168.0          22
# 4   45576e63-0b83-4a72-a4dc-febca9c8b2c3       5.0          167.9          22
# 5   df50491c-b5e4-4248-af99-14907a298544       6.0          167.8          22
# 6   95c7c464-a506-4036-8cc8-5ac9a4eb52bc       7.0          167.6          22
# 7   1fde9f8e-1014-4686-aee6-191b7368fb23       8.0          167.5          22
# 8   a3ea8226-67c1-4d89-a5a1-26dd1b33c7af       9.0          167.5          22
# 9   97a8a1b1-6682-4ded-b89b-3f4f6e19d89f      10.0          167.2          22
# 10  2055c1a5-fc7c-493f-9308-5f89fbfe959e      11.0          167.1          22
# 11  afee4059-b21b-4471-9121-fc8713f18b41      12.0          166.6          22
# 12  cda22f36-d64a-40e1-9677-df625837f59c      13.0          166.4          22
# 13  85cc6d47-c0ef-49cb-a5b6-f53d257a9979      14.0          166.4          22
# 14  dc8a9273-d3e2-46dc-a8b1-4b333271956a      15.0          165.5          22
# 15  1aad97f1-4bec-4c1e-a765-c1b8f2b58716      16.0          165.5          22
# 16  63d731f5-d421-42a5-ab03-45e159b39c99      17.0          165.5          22
# 17  affe81bf-b047-4b96-925f-5cbd9753338b      18.0          165.4          22
# 18  c08b5457-b1cb-4d77-b79a-6840cd906086       NaN          167.2          11
# 19  6da5f729-3a66-4dc5-8624-b0e2eb0496d6       NaN          167.2          11
# 20  aefc0dda-c315-4de4-a925-ce25c7bc7b24       NaN          166.9          10
# 21  7a02569d-9fe9-4899-a7e1-fa5dc0f8db49       NaN          166.6           9
# 22  55638c09-5608-4001-ba16-68744fc11d9b       NaN          165.4           6
# 23  55dc3421-da2f-4f7a-9926-38b32db781eb       NaN          165.6           6
#
#           time  points   status                              rider.id  \
# 0   42:13.1980      25   INSTND  ff225c9d-64a2-43ac-a70e-62cf385a85a1
# 1   42:13.5440      20   INSTND  ba579548-f026-402b-a607-38db5317d33f
# 2   42:14.5490      16   INSTND  40c19361-abe5-46e8-bed9-b3fa648dd7ac
# 3   42:15.4400      13   INSTND  4cff2dfb-2feb-4264-9a17-8a67189c204c
# 4   42:17.2970      11   INSTND  f55b433d-38b8-4d1d-bb3a-a709c82a0260
# 5   42:18.0410      10   INSTND  9a441928-d1af-452d-afce-fa028c044932
# 6   42:22.0080       9   INSTND  56475aa3-f3d1-485a-b6db-ca1149e1b6fa
# 7   42:23.7340       8   INSTND  487440af-cfa9-478a-903b-4e893ee18d3a
# 8   42:23.7410       7   INSTND  fcdd5500-a769-4ff4-8b9e-080d1849ff42
# 9   42:28.1650       6   INSTND  201ae7a4-0dc7-4191-be71-d91ac0330090
# 10  42:29.9100       5   INSTND  a73f8ef2-784f-4f52-8511-1d315fd3a459
# 11  42:36.4140       4   INSTND  66ee98b2-239c-487f-8913-aab8493ce280
# 12  42:40.4810       3   INSTND  7b0687b0-90bd-4ad6-b157-8c66fb8a93cf
# 13  42:40.5720       2   INSTND  06989a4b-12bc-4cb5-bad6-bb8dab9097f3
# 14  42:54.3050       1   INSTND  09bd7ecd-ee3f-4e20-8efa-c200f724c642
# 15  42:54.3170       0   INSTND  e38443a0-a5f5-4616-825c-9db2adc24a55
# 16  42:54.5470       0   INSTND  6c33de41-f014-4f17-8dc9-e6f36e61026a
# 17  42:55.5550       0   INSTND  58448742-f520-466a-a1a1-bf3286cce9c3
# 18  21:13.8350       0  OUTSTND  9cb55304-0ac1-401c-beb6-1a4f445018a4
# 19  21:13.8000       0  OUTSTND  5cbd7eb6-ccfc-4b9f-aad1-ede25d394f7b
# 20  19:19.8860       0  OUTSTND  1abd2de7-9046-4d0a-88e3-ad801dcc235b
# 21  17:25.7820       0  OUTSTND  e7e4c72e-952e-4f64-8e8a-a47ff590fade
# 22  11:42.3060       0  OUTSTND  6e940243-5167-4cc3-a343-a74337369b94
# 23  11:41.3210       0  OUTSTND  ab06dbae-7d6e-47c3-b63f-b7ac6b7d3bcd
#
#           rider.full_name rider.country.iso  ...  \
# 0         Enea Bastianini                IT  ...
# 1             Brad Binder                ZA  ...
# 2           Pol Espargaro                ES  ...
# 3         Aleix Espargaro                ES  ...
# 4            Marc Marquez                ES  ...
# 5                Joan Mir                ES  ...
# 6               Alex Rins                ES  ...
# 7            Johann Zarco                FR  ...
# 8        Fabio Quartararo                FR  ...
# 9        Takaaki Nakagami                JP  ...
# 10      Franco Morbidelli                IT  ...
# 11       Maverick Viñales                ES  ...
# 12            Luca Marini                IT  ...
# 13       Andrea Dovizioso                IT  ...
# 14           Remy Gardner                AU  ...
# 15          Darryn Binder                ZA  ...
# 16  Fabio Di Giannantonio                IT  ...
# 17         Raul Fernandez                ES  ...
# 18      Francesco Bagnaia                IT  ...
# 19           Jorge Martin                ES  ...
# 20        Miguel Oliveira                PT  ...
# 21           Alex Marquez                ES  ...
# 22            Jack Miller                AU  ...
# 23        Marco Bezzecchi                IT  ...
#
#                           team.season.id team.season.year  \
# 0   db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 1   db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 2   db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 3   db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 4   db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 5   db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 6   db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 7   db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 8   db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 9   db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 10  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 11  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 12  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 13  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 14  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 15  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 16  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 17  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 18  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 19  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 20  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 21  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 22  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
# 23  db8dc197-c7b2-4c1b-b3a4-6dc534c014ef             2022
#
#     team.season.current                        constructor.id  \
# 0                 False  b9d93efb-3cd0-4681-9de4-c412a866d568
# 1                 False  be77c017-cc37-41eb-aa09-2977f1789b0f
# 2                 False  3a036648-7b14-4257-8c62-245e47e4d42b
# 3                 False  10d5e2bc-4b0b-4875-b936-3962fbb1b877
# 4                 False  3a036648-7b14-4257-8c62-245e47e4d42b
# 5                 False  e1824280-b485-4f63-b176-834bbf47aa1c
# 6                 False  e1824280-b485-4f63-b176-834bbf47aa1c
# 7                 False  b9d93efb-3cd0-4681-9de4-c412a866d568
# 8                 False  babb4c4c-3608-4811-93ad-3b88cc407547
# 9                 False  3a036648-7b14-4257-8c62-245e47e4d42b
# 10                False  babb4c4c-3608-4811-93ad-3b88cc407547
# 11                False  10d5e2bc-4b0b-4875-b936-3962fbb1b877
# 12                False  b9d93efb-3cd0-4681-9de4-c412a866d568
# 13                False  babb4c4c-3608-4811-93ad-3b88cc407547
# 14                False  be77c017-cc37-41eb-aa09-2977f1789b0f
# 15                False  babb4c4c-3608-4811-93ad-3b88cc407547
# 16                False  b9d93efb-3cd0-4681-9de4-c412a866d568
# 17                False  be77c017-cc37-41eb-aa09-2977f1789b0f
# 18                False  b9d93efb-3cd0-4681-9de4-c412a866d568
# 19                False  b9d93efb-3cd0-4681-9de4-c412a866d568
# 20                False  be77c017-cc37-41eb-aa09-2977f1789b0f
# 21                False  3a036648-7b14-4257-8c62-245e47e4d42b
# 22                False  b9d93efb-3cd0-4681-9de4-c412a866d568
# 23                False  b9d93efb-3cd0-4681-9de4-c412a866d568
#
#    constructor.name constructor.legacy_id  gap.first gap.lap  \
# 0            Ducati                   110      0.000       0
# 1               KTM                   298      0.346       0
# 2             Honda                     1      1.351       0
# 3           Aprilia                     7      2.242       0
# 4             Honda                     1      4.099       0
# 5            Suzuki                     2      4.843       0
# 6            Suzuki                     2      8.810       0
# 7            Ducati                   110     10.536       0
# 8            Yamaha                     3     10.543       0
# 9             Honda                     1     14.967       0
# 10           Yamaha                     3     16.712       0
# 11          Aprilia                     7     23.216       0
# 12           Ducati                   110     27.283       0
# 13           Yamaha                     3     27.374       0
# 14              KTM                   298     41.107       0
# 15           Yamaha                     3     41.119       0
# 16           Ducati                   110     41.349       0
# 17              KTM                   298     42.357       0
# 18           Ducati                   110      0.000      11
# 19           Ducati                   110      0.000      11
# 20              KTM                   298      0.000      12
# 21            Honda                     1      0.000      13
# 22           Ducati                   110      0.000      16
# 23           Ducati                   110      0.000      16
#
#                                 event_id  event_name
# 0   0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 1   0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 2   0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 3   0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 4   0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 5   0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 6   0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 7   0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 8   0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 9   0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 10  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 11  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 12  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 13  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 14  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 15  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 16  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 17  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 18  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 19  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 20  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 21  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 22  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
# 23  0561c82b-4738-4bb6-88d0-6df77f002a43         QAT
#
# [24 rows x 27 columns]

# %% [markdown]
# #### Retrieving results for multiple seasons

# %%
dataframes = []
for season in range(2012, 2023):
    motogp.load_season(season=season)
    dataframes.append(motogp.results())

df = pd.concat(dataframes)
# Out:
# Loaded MotoGP season 2012 (1b0857d2-afa8-4b59-b876-079c68084527)
# Available categories: ['MotoGP', 'Moto2', 'Moto3']
# Available events: ['QAT', 'SPA', 'POR', 'FRA', 'CAT', 'GBR', 'NED', 'GER', 'ITA', 'USA', 'INP', 'CZE', 'RSM', 'ARA', 'JPN', 'MAL', 'AUS', 'VAL']
# Retrieving results for all events in season 2012:
# 	* QAT (94d5ff47-e965-4c6d-bed3-66234d4774a3) ... Ok.
# 	* SPA (526dfa56-79c1-4bcb-8e92-02b2668a0d05) ... Ok.
# 	* POR (d1e8e126-21c9-4a39-a5b9-36b41ba0cfdf) ... Ok.
# 	* FRA (70ea05e1-1bb5-45ab-a028-c450c0b5ee32) ... Ok.
# 	* CAT (19cdbb83-61ef-4c05-88f4-49ddfe6f321c) ... Ok.
# 	* GBR (e2de2e44-ba61-4585-9f8f-3bf10eb91e42) ... Ok.
# 	* NED (664ec94d-c710-4acd-afc1-e3a92a379083) ... Ok.
# 	* GER (65525c13-e599-477b-9af2-ac8b4424f659) ... Ok.
# 	* ITA (fa158cf8-d529-4cc7-9e12-807010c8c0ed) ... Ok.
# 	* USA (3efbe089-3cd5-4ad4-9673-d95497c5ddfb) ... Ok.
# 	* INP (3268be9f-62c2-4fcd-a72b-cbdb75242f1d) ... Ok.
# 	* CZE (d88596e6-d163-43e4-8ff3-443149da9abc) ... Ok.
# 	* RSM (af6e0ae6-f609-4a20-977e-5cef6098a04e) ... Ok.
# 	* ARA (f2be1ea3-57c2-4169-b840-e4795aad9484) ... Ok.
# 	* JPN (e30a3c38-aceb-4cba-8ede-d9ce62a1cf05) ... Ok.
# 	* MAL (cd25c1c6-2df4-407d-81db-522218f75adf) ... Ok.
# 	* AUS (59f0e126-065d-480d-a84f-e9200f7efcf3) ... Ok.
# 	* VAL (2441e043-3137-4962-8cb5-81fb47e8f094) ... Ok.
# Dataframe concatenated.
# Loaded MotoGP season 2013 (a0def534-ce1b-492c-bc46-e87e95d28230)
# Available categories: ['MotoGP', 'Moto2', 'Moto3']
# Available events: ['QAT', 'AME', 'SPA', 'FRA', 'ITA', 'CAT', 'NED', 'GER', 'USA', 'INP', 'CZE', 'GBR', 'RSM', 'ARA', 'MAL', 'AUS', 'JPN', 'VAL']
# Retrieving results for all events in season 2013:
# 	* QAT (e5c416e6-40f1-43f4-85a1-ae0486fb59e1) ... Ok.
# 	* AME (7ea3451f-4b9f-4b1e-bb01-ff1ae5f0885f) ... Ok.
# 	* SPA (414f83d5-f7fc-44a3-941b-010598a1a19e) ... Ok.
# 	* FRA (191f0a25-b39e-4b6b-a0f3-e6aa7382e7cc) ... Ok.
# 	* ITA (7e2529b7-a732-4351-bb0e-e1c58038843a) ... Ok.
# 	* CAT (a420a80e-ec5d-48db-a25c-e23bed8a8064) ... Ok.
# 	* NED (62c9d85f-846c-4b16-93f9-6857eea2f1cd) ... Ok.
# 	* GER (de11fa5b-feca-49b6-9d19-24702a21b2ab) ... Ok.
# 	* USA (094709e4-31f8-45dc-bfe6-324788bb345f) ... Ok.
# 	* INP (2ba0a08e-3b9f-400f-8513-6def050bf14a) ... Ok.
# 	* CZE (3198d637-b762-4f8d-a67d-bc52fd4127c8) ... Ok.
# 	* GBR (9b726286-adcb-47ff-8a7e-bc53cc6fbfcb) ... Ok.
# 	* RSM (6b0b74e4-ca8e-4d38-8806-d0e331421c1f) ... Ok.
# 	* ARA (6bc77901-194d-4075-b96c-354797987fb1) ... Ok.
# 	* MAL (53c09084-725d-47c5-91dc-d488760d2c20) ... Ok.
# 	* AUS (265bbb13-e15c-4be5-9254-e62df872b60a) ... Ok.
# 	* JPN (4f97088a-79c9-492a-a934-a570035ffbe4) ... Ok.
# 	* VAL (6bad463a-bd6b-43ad-a986-fdcc96838f63) ... Ok.
# Dataframe concatenated.
# Loaded MotoGP season 2014 (bf5c15b5-f062-4a88-a304-29892743108d)
# Available categories: ['MotoGP', 'Moto2', 'Moto3']
# Available events: ['QAT', 'AME', 'ARG', 'SPA', 'FRA', 'ITA', 'CAT', 'NED', 'GER', 'INP', 'CZE', 'GBR', 'RSM', 'ARA', 'JPN', 'AUS', 'MAL', 'VAL']
# Retrieving results for all events in season 2014:
# 	* QAT (9e14f35f-f7f2-4ba6-8898-87ba072c3437) ... Ok.
# 	* AME (2c09fdaf-abff-487c-8e22-2c35309edb36) ... Ok.
# 	* ARG (31751038-df46-40f8-84ac-2e72ed604550) ... Ok.
# 	* SPA (8b1cdb37-ab38-4100-b682-14acd26f8e23) ... Ok.
# 	* FRA (70c713cf-281d-4067-a5d4-2d658d9da1a1) ... Ok.
# 	* ITA (52352fdf-c02c-4bf2-80a2-ce39759abd30) ... Ok.
# 	* CAT (8219b06f-9d87-438f-ac5b-beb230482cbd) ... Ok.
# 	* NED (29b06aa5-11c8-4bd4-9c0e-68c285224c1e) ... Ok.
# 	* GER (dd0c6253-8dec-47c5-99fd-da656c02394e) ... Ok.
# 	* INP (224493df-7c63-435c-af49-251e15fc64f7) ... Ok.
# 	* CZE (df783f02-e3e9-4654-90e0-13d164061291) ... Ok.
# 	* GBR (892de713-8179-46b7-9d1c-bc7d85cacd55) ... Ok.
# 	* RSM (8d51ad93-e751-47ad-9c87-ed58e8f65f13) ... Ok.
# 	* ARA (f7e30681-83a4-43c7-b2d6-d3c50b38f639) ... Ok.
# 	* JPN (be46a3ac-af9e-41e9-bf45-0c3b7a3e2793) ... Ok.
# 	* AUS (8b0e6917-b689-4ab7-a96d-76b7ba9f5610) ... Ok.
# 	* MAL (1b869fa9-da9e-4ee5-90c3-fd3e171ad5ae) ... Ok.
# 	* VAL (4977e88d-4405-4538-8506-1ead10ed840f) ... Ok.
# Dataframe concatenated.
# Loaded MotoGP season 2015 (cbe871d8-d8fa-47cb-8b63-cabe0015223e)
# Available categories: ['MotoGP', 'Moto2', 'Moto3']
# Available events: ['QAT', 'AME', 'ARG', 'SPA', 'FRA', 'ITA', 'CAT', 'NED', 'GER', 'INP', 'CZE', 'GBR', 'RSM', 'ARA', 'JPN', 'AUS', 'MAL', 'VAL']
# Retrieving results for all events in season 2015:
# 	* QAT (c68ece2b-fc82-42b1-a1fb-6a0f4af01d64) ... Ok.
# 	* AME (902eaad6-a45f-4afd-8ea2-9a409ecc6984) ... Ok.
# 	* ARG (a4b6173e-c2b7-4a26-b336-91e025aecfbe) ... Ok.
# 	* SPA (4862fda0-e20d-401a-b844-51a1987a7358) ... Ok.
# 	* FRA (344ffc63-16b3-4660-8e51-14332d308fd1) ... Ok.
# 	* ITA (5d08e185-a070-485b-ae74-7a748c73b37c) ...
